# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm 
import json

# %%
filenames = []
for file in os.listdir('/Users/mihir/Desktop/Projects/t20 wc score predictor/dataset/t20s'):
    filenames.append(os.path.join('/Users/mihir/Desktop/Projects/t20 wc score predictor/dataset/t20s',file))

# %%
filenames[0:5]
# Out:
# ['/Users/mihir/Desktop/Projects/t20 wc score predictor/dataset/t20s/1359789.yaml',
#  '/Users/mihir/Desktop/Projects/t20 wc score predictor/dataset/t20s/1173055.yaml',
#  '/Users/mihir/Desktop/Projects/t20 wc score predictor/dataset/t20s/951375.yaml',
#  '/Users/mihir/Desktop/Projects/t20 wc score predictor/dataset/t20s/1394759.yaml',
#  '/Users/mihir/Desktop/Projects/t20 wc score predictor/dataset/t20s/1400974.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = pd.concat([final_df, df], ignore_index=True)
        counter += 1
# Out:
#  75%|█████████████████████████████▎         | 2689/3581 [21:30<07:08,  2.08it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[6], line 5
#       3 for file in tqdm(filenames):
#       4     with open(file, 'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id'] = counter
#       7         final_df = pd.concat([final_df, df], ignore_index=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/json/_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
# ...

# %%
final_df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...               0.92
# 1     [{'1st innings': {'team': 'West Indies', 'deli...               0.91
# 2     [{'1st innings': {'team': 'India', 'deliveries...               0.91
# 3     [{'1st innings': {'team': 'Malaysia', 'deliver...               0.92
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...               0.92
# ...                                                 ...                ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.92
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
# ...

# %%
threshold = 0.5
final_df = final_df.loc[:, final_df.isnull().mean() < threshold]

final_df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...               0.92
# 1     [{'1st innings': {'team': 'West Indies', 'deli...               0.91
# 2     [{'1st innings': {'team': 'India', 'deliveries...               0.91
# 3     [{'1st innings': {'team': 'Malaysia', 'deliver...               0.92
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...               0.92
# ...                                                 ...                ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.92
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
# ...

# %%
final_df.columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.balls_per_over', 'info.city', 'info.dates', 'info.gender',
#        'info.match_type', 'info.match_type_number', 'info.outcome.winner',
#        'info.overs', 'info.player_of_match', 'info.teams', 'info.toss.winner',
#        'info.toss.decision', 'info.umpires', 'info.venue', 'match_id'],
#       dtype='object')

# %%
backup = final_df.copy()

# %%
final_df.drop(columns = [
    'meta.data_version',
    'meta.created',
    'info.balls_per_over'   ], inplace = True)
# Out:
# /var/folders/qg/km03k0gn1yn690bk_brhvb3c0000gn/T/ipykernel_38011/3234434094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns = [

# %%
final_df
# Out:
#                                                 innings  meta.revision  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...              1
# 1     [{'1st innings': {'team': 'West Indies', 'deli...              1
# 2     [{'1st innings': {'team': 'India', 'deliveries...              2
# 3     [{'1st innings': {'team': 'Malaysia', 'deliver...              1
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...              1
# ...                                                 ...            ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...              2
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...              1
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...              2
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...              1
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...              3
#
#          info.city    info.dates info.gender info.match_type  \
# ...

# %%
final_df.columns
# Out:
# Index(['innings', 'meta.revision', 'info.city', 'info.dates', 'info.gender',
#        'info.match_type', 'info.match_type_number', 'info.outcome.winner',
#        'info.overs', 'info.player_of_match', 'info.teams', 'info.toss.winner',
#        'info.toss.decision', 'info.umpires', 'info.venue', 'match_id'],
#       dtype='object')

# %%
final_df.drop(columns=['meta.revision', 'info.match_type_number' ], inplace = True)
# Out:
# /var/folders/qg/km03k0gn1yn690bk_brhvb3c0000gn/T/ipykernel_38011/2598767534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['meta.revision', 'info.match_type_number' ], inplace = True)

# %%
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 1     [{'1st innings': {'team': 'West Indies', 'deli...      Canberra
# 2     [{'1st innings': {'team': 'India', 'deliveries...     Bangalore
# 3     [{'1st innings': {'team': 'Malaysia', 'deliver...         Bangi
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type   info.outcome.winner  \
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male      1783
# female     906
# Name: count, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    2685
# 50       4
# Name: count, dtype: int64

# %%
backup1 = final_df.copy()

# %%
final_df = final_df[final_df['info.gender']=='male']
final_df.drop(columns = ['info.gender'])
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# ...

# %%
final_df.drop(columns = ['info.gender'])
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.match_type info.outcome.winner  info.overs  \
# ...

# %%
final_df = final_df[final_df['info.overs']=='20']

# %%
final_df
# Out:
# Empty DataFrame
# Columns: [innings, info.city, info.dates, info.gender, info.match_type, info.outcome.winner, info.overs, info.player_of_match, info.teams, info.toss.winner, info.toss.decision, info.umpires, info.venue, match_id]
# Index: []

# %%
final_df = backup1

# %%
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 1     [{'1st innings': {'team': 'West Indies', 'deli...      Canberra
# 2     [{'1st innings': {'team': 'India', 'deliveries...     Bangalore
# 3     [{'1st innings': {'team': 'Malaysia', 'deliver...         Bangi
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type   info.outcome.winner  \
# ...

# %%
backup2 = final_df.copy()

# %%
final_df = final_df[final_df['info.gender']=='male']
final_df.drop(columns = ['info.gender'])
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# ...

# %%
final_df.drop(columns = ['info.gender'])
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.match_type info.outcome.winner  info.overs  \
# ...

# %%
backup2 = final_df.copy()

# %%
final_df = final_df[final_df['info.overs']!='50']

# %%
final_df.drop(columns = 'info.overs')
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# ...

# %%
final_df.drop(columns = 'info.gender')
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.match_type info.outcome.winner  info.overs  \
# ...

# %%
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male    1783
# Name: count, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    1783
# Name: count, dtype: int64

# %%
final_df = final_df.drop(columns = ['info.gender', 'info.overs'], inplace = True)

# %%
backup2
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# ...

# %%
final_df = backup1[backup1['info.gender']=='male']

# %%
final_df = backup1[backup1['info.gender']=='male']

# %%
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# ...

# %%
backup = final_df.copy()

# %%
backup
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# ...

# %%
final_df.drop(columns = ['info.gender'],inplace = True)
# Out:
# /var/folders/qg/km03k0gn1yn690bk_brhvb3c0000gn/T/ipykernel_38011/3971679261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns = ['info.gender'],inplace = True)

# %%
final_df.drop(columns = ['info.overs'],inplace = True)
# Out:
# /var/folders/qg/km03k0gn1yn690bk_brhvb3c0000gn/T/ipykernel_38011/247875397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns = ['info.overs'],inplace = True)

# %%
final_df
# Out:
#                                                 innings     info.city  \
# 0     [{'1st innings': {'team': 'Bermuda', 'deliveri...  Buenos Aires
# 4     [{'1st innings': {'team': 'Nigeria', 'deliveri...         Lagos
# 5     [{'1st innings': {'team': 'Rwanda', 'deliverie...   Kigali City
# 7     [{'1st innings': {'team': 'Nepal', 'deliveries...      Kirtipur
# 8     [{'1st innings': {'team': 'Scotland', 'deliver...     Edinburgh
# ...                                                 ...           ...
# 2684  [{'1st innings': {'team': 'Zimbabwe', 'deliver...      Auckland
# 2685  [{'1st innings': {'team': 'Pakistan', 'deliver...      Trinidad
# 2686  [{'1st innings': {'team': 'Pakistan', 'deliver...      Hangzhou
# 2687  [{'1st innings': {'team': 'Afghanistan', 'deli...        Nagpur
# 2688  [{'1st innings': {'team': 'Pakistan', 'deliver...           NaN
#
#         info.dates info.match_type info.outcome.winner info.player_of_match  \
# ...

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    1783
# Name: count, dtype: int64

# %%
import pickle
pickle.dump(final_df, open('dataset_level1.pkl11','wb'))

# %%
# Extracting only 1st innings data here onwards

# %%
matches = pickle.load(open('dataset_level1.pkl11','rb'))

# %%
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'bowler': 'AM Patel',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'non_striker': 'T Manders',
#    'batsman': 'KS Leverock'}},
#  {0.2: {'bowler': 'AM Patel',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'T Manders',
#    'batsman': 'KS Leverock'}},
#  {0.3: {'bowler': 'AM Patel',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'T Manders',
#    'batsman': 'KS Leverock'}},
#  {0.4: {'bowler': 'AM Patel',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'non_striker': 'T Manders',
#    'batsman': 'KS Leverock'}},
#  {0.5: {'bowler': 'AM Patel',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'T Manders',
#    'batsman': 'KS Leverock'}},
#  {0.6: {'bowler': 'AM Patel',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'non_striker': 'T Manders',
#    'batsman': 'KS Leverock'}},
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count += 1
        continue
    count += 1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except KeyError:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
        'match_id': match_id,
        'teams': teams,
        'batting_team': batting_team,
        'ball': ball_of_match,
        'batsman': batsman,
        'bowler': bowler,
        'runs': runs,
        'player_dismissed': player_of_dismissed,
        'city': city,
        'venue': venue
    })
    delivery_df = pd.concat([delivery_df, loop_df], ignore_index=True)

# %%
delivery_df
# Out:
#         match_id                    teams batting_team  ball        batsman  \
# 0              2        [Bermuda, Panama]      Bermuda   0.1    KS Leverock
# 1              2        [Bermuda, Panama]      Bermuda   0.2    KS Leverock
# 2              2        [Bermuda, Panama]      Bermuda   0.3    KS Leverock
# 3              2        [Bermuda, Panama]      Bermuda   0.4    KS Leverock
# 4              2        [Bermuda, Panama]      Bermuda   0.5    KS Leverock
# ...          ...                      ...          ...   ...            ...
# 214645      1784  [New Zealand, Pakistan]     Pakistan  19.2  Sohail Tanvir
# 214646      1784  [New Zealand, Pakistan]     Pakistan  19.3  Sohail Tanvir
# 214647      1784  [New Zealand, Pakistan]     Pakistan  19.4   Abdul Razzaq
# 214648      1784  [New Zealand, Pakistan]     Pakistan  19.5  Mohammad Amir
# 214649      1784  [New Zealand, Pakistan]     Pakistan  19.6  Mohammad Amir
#
# ...

# %%
# Feature Engineering

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl, axis=1)

# %%
backup = delivery_df.copy()

# %%
delivery_df.drop(columns = 'teams', inplace = True)

# %%
delivery_df
# Out:
#         match_id batting_team  ball        batsman      bowler  runs  \
# 0              2      Bermuda   0.1    KS Leverock    AM Patel     1
# 1              2      Bermuda   0.2    KS Leverock    AM Patel     0
# 2              2      Bermuda   0.3    KS Leverock    AM Patel     0
# 3              2      Bermuda   0.4    KS Leverock    AM Patel     1
# 4              2      Bermuda   0.5    KS Leverock    AM Patel     0
# ...          ...          ...   ...            ...         ...   ...
# 214645      1784     Pakistan  19.2  Sohail Tanvir  TG Southee     6
# 214646      1784     Pakistan  19.3  Sohail Tanvir  TG Southee     0
# 214647      1784     Pakistan  19.4   Abdul Razzaq  TG Southee     1
# 214648      1784     Pakistan  19.5  Mohammad Amir  TG Southee     2
# 214649      1784     Pakistan  19.6  Mohammad Amir  TG Southee     0
#
#        player_dismissed          city  \
# 0                     0  Buenos Aires
# 1                     0  Buenos Aires
# ...

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Bermuda', 'Nigeria', 'Rwanda', 'Nepal', 'Scotland', 'Netherlands',
#        'Oman', 'West Indies', 'Malta', 'Canada', 'Swaziland', 'India',
#        'England', 'South Africa', 'Argentina', 'Ghana', 'Portugal',
#        'Pakistan', 'Zimbabwe', 'Bahrain', 'Bangladesh', 'Isle of Man',
#        'Cameroon', 'New Zealand', 'Spain', 'Indonesia', 'Afghanistan',
#        'Gibraltar', 'Tanzania', 'China', 'Maldives', 'Kenya', 'Slovenia',
#        'Hungary', 'Romania', 'Bhutan', 'Czech Republic', 'Australia',
#        'Kuwait', 'Malaysia', 'United Arab Emirates', 'Ireland',
#        'Hong Kong', 'Denmark', 'Mali', 'Bulgaria', 'Austria', 'Botswana',
#        'Saudi Arabia', 'Vanuatu', 'Japan', 'Panama', 'Thailand',
#        'Sri Lanka', 'Luxembourg', 'Singapore', 'Papua New Guinea',
#        'Finland', 'Germany', 'Uganda', 'Croatia', 'France', 'Serbia',
#        'Fiji', 'Cyprus', 'Belgium', 'Sweden', 'Guernsey', 'Namibia',
# ...

# %%
len(delivery_df['bowling_team'].unique())
# Out:
# 98

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'West Indies',
    'Nepal',
    'Scotland',
    'Netherlands',
    'Canada',
    'England',
    'South Africa',
    'Oman',
    'Pakistan',
    'New Zealand',
    'Afghanistan',
    'Ireland',
    'Sri Lanka',
    'United States of America',
    'Papua New Guinea',
    'Uganda',
    'Namibia',
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#         match_id batting_team  ball        batsman      bowler  runs  \
# 373            5        Nepal   0.1      K Bhurtel   VJ Kingma     0
# 374            5        Nepal   0.2      K Bhurtel   VJ Kingma     1
# 375            5        Nepal   0.3   Aasif Sheikh   VJ Kingma     0
# 376            5        Nepal   0.4   Aasif Sheikh   VJ Kingma     0
# 377            5        Nepal   0.5   Aasif Sheikh   VJ Kingma     0
# ...          ...          ...   ...            ...         ...   ...
# 214645      1784     Pakistan  19.2  Sohail Tanvir  TG Southee     6
# 214646      1784     Pakistan  19.3  Sohail Tanvir  TG Southee     0
# 214647      1784     Pakistan  19.4   Abdul Razzaq  TG Southee     1
# 214648      1784     Pakistan  19.5  Mohammad Amir  TG Southee     2
# 214649      1784     Pakistan  19.6  Mohammad Amir  TG Southee     0
#
#        player_dismissed      city  \
# 373                   0  Kirtipur
# 374                   0  Kirtipur
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]
output
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 373            5        Nepal  Netherlands   0.1     0                0
# 374            5        Nepal  Netherlands   0.2     1                0
# 375            5        Nepal  Netherlands   0.3     0                0
# 376            5        Nepal  Netherlands   0.4     0                0
# 377            5        Nepal  Netherlands   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 214645      1784     Pakistan  New Zealand  19.2     6                0
# 214646      1784     Pakistan  New Zealand  19.3     0    Sohail Tanvir
# 214647      1784     Pakistan  New Zealand  19.4     1                0
# 214648      1784     Pakistan  New Zealand  19.5     2                0
# 214649      1784     Pakistan  New Zealand  19.6     0    Mohammad Amir
#
#             city                                              venue
# ...

# %%
pickle.dump(output,open('dataset_level1.pkl12','wb'))
